# %%
import Pkg

Pkg.add("MLDataUtils")
Pkg.add("DelimitedFiles")
Pkg.add("Flux")
Pkg.add("DataFrames")
Pkg.add("LaTeXStrings")
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.6/Project.toml`
#   No Changes to `~/.julia/environments/v1.6/Manifest.toml`

# %%
using ImageCore
using MLDatasets
using LinearAlgebra
using DelimitedFiles
using Flux
using MLDataUtils
using Plots
using Printf
using Statistics
using DataFrames
using LaTeXStrings
using StatsBase

# %%
train_x, train_y = MNIST.traindata()
test_x, test_y = MNIST.testdata()

train_x = convert(Array{Float64, 3}, permutedims(train_x, [3, 2, 1]))
test_x = convert(Array{Float64, 3}, permutedims(test_x, [3, 2, 1]))

train_y = train_y .+ 1
test_y = test_y .+ 1

no_samples = size(train_x)[1]
no_pixels = size(train_x)[2]
no_labels = length(unique(train_y))[1];

# %%
# Given we are working with an MLP, we will flatten the vectors

train_x = reduce(vcat, [Matrix([train_x[i, :, :]...]') for i in 1:no_samples])
test_x = reduce(vcat, [Matrix([test_x[i, :, :]...]') for i in 1:size(test_x)[1]]);

# %%
MNIST.convert2image(MNIST.traintensor(1))
# Out:
# 28×28 reinterpret(reshape, Gray{N0f8}, ::Array{N0f8,2}) with eltype Gray{N0f8}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %%
random_samples = rand(1:no_samples, 9);
plt = plot(layout = (3, 3), aspect_ratio = :equal, axis = false)

for (i, sample) in enumerate(random_samples)
    heatmap!(plt, 
        reshape(train_x[sample, :], no_pixels, no_pixels), 
        subplot = i, 
        yflip = true, 
        color = :grays, 
        colorbar = false, 
        axis = nothing)
end

display(plt)

# %%
function train_test_split(indices, shuffle, split)
    index_list = shuffle == 1 ? shuffleobs(indices) : deepcopy(indices)
    return splitobs(index_list, at = split)
end

train_idx, val_idx = train_test_split(1:no_samples, 1, 0.8);

# %% [markdown]
# # Three Layer MLP

# %%
# We will start by considering a Three Layer MLP 

mutable struct ThreeLayerPerceptron
    W1 ::Matrix{Float64}
    b1 ::Vector{Float64}
    W2 ::Matrix{Float64}
    b2 ::Vector{Float64}
    W3 ::Matrix{Float64}
    b3 ::Vector{Float64}
end

# Define a constructor

ThreeLayerPerceptron(no_hidden_nodes, no_features, no_classes) = ThreeLayerPerceptron(
    randn(no_hidden_nodes, no_features), 
    randn(no_hidden_nodes),
    randn(no_hidden_nodes, no_hidden_nodes),
    randn(no_hidden_nodes),
    randn(no_classes, no_hidden_nodes),
    randn(no_classes))

#Define the helper functions for this network

f(m::ThreeLayerPerceptron, x) = softmax(m.W3 * logistic.(m.W2 * logistic.(m.W1 * x + m.b1) + m.b2) + m.b3)
predict(m::ThreeLayerPerceptron, x) = findmax(f(m, x))[2];
loss(m::ThreeLayerPerceptron, x, y) = -log(f(m, x)[Int(y)])
# Out:
# loss (generic function with 1 method)

# %%
#Define helper functions for gradient calculations

function zero(m::ThreeLayerPerceptron)
    gradm = deepcopy(m)
    fill!(gradm.W1, 0)
    fill!(gradm.W2, 0)
    fill!(gradm.W3, 0)
    fill!(gradm.b1, 0)
    fill!(gradm.b2, 0)
    fill!(gradm.b3, 0)
    return gradm
end

function flatten(m::ThreeLayerPerceptron)
    toflatten = (m.W1, m.b1, m.W2, m.b2, m.W3, m.b3) 
    flatvec = vcat([x[:] for x in toflatten]...)
    return flatvec
end

function unflatten!(m::ThreeLayerPerceptron, vec)
    tounflatten = (m.W1, m.b1, m.W2, m.b2, m.W3, m.b3)
    offset = 1
    for parameter in tounflatten
        parameter[:] = vec[offset:offset + length(parameter) - 1]
        offset += length(parameter)
    end
end

function accuracy(m::ThreeLayerPerceptron, X, y)
    correct = 0
    no_samples = length(y)
    for i in 1:no_samples
        y_pred = predict(m, X[i, :])
        correct += y_pred == y[i]
    end
    acc = correct / no_samples
    return acc
end

logistic(x) = 1 / (1 + exp(-x))
logistic_prime(x) = logistic(x) * (1 - logistic(x))

outer(x, y) = x.*y'

function lossprime!(gradm, m, x, y)
    
    # Feed Forward
    
    a0 = x
    z1 = m.W1 * a0 + m.b1 
    a1 = logistic.(z1)
    z2 = m.W2 * a1 + m.b2 
    a2 = logistic.(z2)
    z3 = m.W3 * a2 + m.b3 
    a3 = softmax(z3)
    
    #backwards
    
    a3[Int(y)]  -= 1
    error_3 = a3
    error_2 = logistic_prime.(z2) .* m.W3' * error_3
    error_1 = logistic_prime.(z1) .* m.W2' * error_2
    
    gradm.b3 += error_3
    gradm.b2 += error_2
    gradm.b1 += error_1
    
    gradm.W3 += outer(error_3, a2)
    gradm.W2 += outer(error_2, a1)
    gradm.W1 += outer(error_1, a0)
        
end

function step!(m::ThreeLayerPerceptron, gradm::ThreeLayerPerceptron, lr, batch)
    vecm = flatten(m)
    vecgm = flatten(gradm)
    vecm .-= lr * vecgm / length(batch)
    unflatten!(m, vecm)
end    

batchify(indices, n, shuff) = shuff ? shuffleobs([indices[i:min(i + n - 1, length(indices)), :] for i in 1:n:length(indices)]) : [indices[i:min(i + n - 1, length(indices)), :] for i in 1:n:length(indices)]

function save_model(f_path, model)
    flat_params = flatten(model)
    writedlm(f_path, flat_params)
end

function load_model(f_path, base_model)
    flat_params = readdlm(f_path)
    unflatten!(base_model, flat_params)
    return base_model
end
# Out:
# load_model (generic function with 1 method)

# %%
FILE_PATH = "model_params/mlp_params.txt"

LEARNING_RATE = 0.1
BATCH_SIZE = 64
MAX_EPOCHS = 500
BEST_VAL_ACC = 0
BEST_MODEL = 0

loss_list = []
training_accuracies = []
val_accuracies = []

mlp = ThreeLayerPerceptron(128, no_pixels^2, no_labels)

for epoch in 1:MAX_EPOCHS
    
    epoch_loss = 0
    batches = batchify(train_idx, BATCH_SIZE, true)
    
    Threads.@threads for batch in batches
        
        batch_loss = 0
        gradm = zero(mlp)
        
        for i in batch
            
            x_train = train_x[i, :]
            y_train = train_y[i]
            
            # Compute loss
            batch_loss += loss(mlp, x_train, y_train)
            
            # Calculate the gradient
            lossprime!(gradm, mlp, x_train, y_train)
        end
        
        epoch_loss += batch_loss
        
        # We take a step in the direction of the gradient

        step!(mlp, gradm, LEARNING_RATE, batch)
        
    end
    
    training_accuracy = accuracy(mlp, train_x[train_idx, :], train_y[train_idx])
    val_accuracy      = accuracy(mlp, train_x[val_idx, :], train_y[val_idx])

    @printf("Epoch: %.0f \t || \t Train Accuracy: %.4f \t || \t Validation Accuracy: %.4f \n", epoch, training_accuracy, val_accuracy)
    
    append!(training_accuracies, training_accuracy)
    append!(val_accuracies, val_accuracy)
    append!(loss_list, epoch_loss)
    
    if val_accuracy > BEST_VAL_ACC
        BEST_VAL_ACC = val_accuracy
        BEST_MODEL = deepcopy(mlp)
    end
    
    training_accuracy < 1.0 || break
    if epoch > 10 && (val_accuracies[end] - minimum(val_accuracies[end-(10-1):end-1]) < 0.0001)
        println("Early Stopping Condition Met")
        break
    end
end

save_model(FILE_PATH, BEST_MODEL)
# Out:
# Epoch: 1 	 || 	 Train Accuracy: 0.7490 	 || 	 Validation Accuracy: 0.7435
# Epoch: 2 	 || 	 Train Accuracy: 0.8132 	 || 	 Validation Accuracy: 0.8043
# Epoch: 3 	 || 	 Train Accuracy: 0.8429 	 || 	 Validation Accuracy: 0.8321
# Epoch: 4 	 || 	 Train Accuracy: 0.8623 	 || 	 Validation Accuracy: 0.8485
# Epoch: 5 	 || 	 Train Accuracy: 0.8756 	 || 	 Validation Accuracy: 0.8601
# Epoch: 6 	 || 	 Train Accuracy: 0.8859 	 || 	 Validation Accuracy: 0.8707
# Epoch: 7 	 || 	 Train Accuracy: 0.8928 	 || 	 Validation Accuracy: 0.8789
# Epoch: 8 	 || 	 Train Accuracy: 0.8996 	 || 	 Validation Accuracy: 0.8830
# Epoch: 9 	 || 	 Train Accuracy: 0.9049 	 || 	 Validation Accuracy: 0.8882
# Epoch: 10 	 || 	 Train Accuracy: 0.9120 	 || 	 Validation Accuracy: 0.8916
# Epoch: 11 	 || 	 Train Accuracy: 0.9159 	 || 	 Validation Accuracy: 0.8957
# Epoch: 12 	 || 	 Train Accuracy: 0.9181 	 || 	 Validation Accuracy: 0.8982
# Epoch: 13 	 || 	 Train Accuracy: 0.9221 	 || 	 Validation Accuracy: 0.9015
# Epoch: 14 	 || 	 Train Accuracy: 0.9251 	 || 	 Validation Accuracy: 0.9035
# Epoch: 15 	 || 	 Train Accuracy: 0.9280 	 || 	 Validation Accuracy: 0.9048
# Epoch: 16 	 || 	 Train Accuracy: 0.9314 	 || 	 Validation Accuracy: 0.9073
# Epoch: 17 	 || 	 Train Accuracy: 0.9336 	 || 	 Validation Accuracy: 0.9086
# Epoch: 18 	 || 	 Train Accuracy: 0.9357 	 || 	 Validation Accuracy: 0.9101
# Epoch: 19 	 || 	 Train Accuracy: 0.9371 	 || 	 Validation Accuracy: 0.9113
# Epoch: 20 	 || 	 Train Accuracy: 0.9393 	 || 	 Validation Accuracy: 0.9135
# Epoch: 21 	 || 	 Train Accuracy: 0.9414 	 || 	 Validation Accuracy: 0.9145
# Epoch: 22 	 || 	 Train Accuracy: 0.9431 	 || 	 Validation Accuracy: 0.9146
# Epoch: 23 	 || 	 Train Accuracy: 0.9446 	 || 	 Validation Accuracy: 0.9156
# Epoch: 24 	 || 	 Train Accuracy: 0.9470 	 || 	 Validation Accuracy: 0.9183
# Epoch: 25 	 || 	 Train Accuracy: 0.9476 	 || 	 Validation Accuracy: 0.9187
# Epoch: 26 	 || 	 Train Accuracy: 0.9495 	 || 	 Validation Accuracy: 0.9196
# Epoch: 27 	 || 	 Train Accuracy: 0.9507 	 || 	 Validation Accuracy: 0.9209
# Epoch: 28 	 || 	 Train Accuracy: 0.9520 	 || 	 Validation Accuracy: 0.9213
# Epoch: 29 	 || 	 Train Accuracy: 0.9529 	 || 	 Validation Accuracy: 0.9219
# Epoch: 30 	 || 	 Train Accuracy: 0.9541 	 || 	 Validation Accuracy: 0.9218
# Epoch: 31 	 || 	 Train Accuracy: 0.9553 	 || 	 Validation Accuracy: 0.9220
# Epoch: 32 	 || 	 Train Accuracy: 0.9569 	 || 	 Validation Accuracy: 0.9243
# Epoch: 33 	 || 	 Train Accuracy: 0.9578 	 || 	 Validation Accuracy: 0.9238
# Epoch: 34 	 || 	 Train Accuracy: 0.9581 	 || 	 Validation Accuracy: 0.9235
# TaskFailedException
#
#     nested task error: InterruptException:
#     Stacktrace:
#       [1] Array
#         @ ./boot.jl:450 [inlined]
#       [2] Array
#         @ ./boot.jl:458 [inlined]
#       [3] Array
#         @ ./boot.jl:465 [inlined]
#       [4] similar
#         @ ./abstractarray.jl:785 [inlined]
#       [5] similar
#         @ ./abstractarray.jl:784 [inlined]
#       [6] similar
#         @ ./broadcast.jl:197 [inlined]
#       [7] similar
#         @ ./broadcast.jl:196 [inlined]
#       [8] copy
#         @ ./broadcast.jl:908 [inlined]
#       [9] materialize
#         @ ./broadcast.jl:883 [inlined]
#      [10] outer(x::Vector{Float64}, y::Vector{Float64})
#         @ Main ./In[9]:43
#      [11] lossprime!(gradm::ThreeLayerPerceptron, m::ThreeLayerPerceptron, x::Vector{Float64}, y::Int64)
#         @ Main ./In[9]:69
#      [12] macro expansion
#         @ ./In[13]:34 [inlined]
#      [13] (::var"#882#threadsfor_fun#12"{SubArray{Matrix{Int64}, 1, Vector{Matrix{Int64}}, Tuple{Vector{Int64}}, false}})(onethread::Bool)
#         @ Main ./threadingconstructs.jl:81
#      [14] (::var"#882#threadsfor_fun#12"{SubArray{Matrix{Int64}, 1, Vector{Matrix{Int64}}, Tuple{Vector{Int64}}, false}})()
#         @ Main ./threadingconstructs.jl:48
#
# Stacktrace:
#  [1] wait
#    @ ./task.jl:322 [inlined]
#  [2] threading_run(func::Function)
#    @ Base.Threads ./threadingconstructs.jl:34
#  [3] macro expansion
#    @ ./threadingconstructs.jl:93 [inlined]
#  [4] top-level scope
#    @ ./In[13]:20
#  [5] eval
#    @ ./boot.jl:360 [inlined]
#  [6] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
function plot_history(train_acc, val_acc)
    trained_epochs = length(train_acc)
    plot_data = hcat(train_acc, val_acc)
    plot(1:trained_epochs, plot_data, title = "Accuracy over Training", label = ["Train" "Validation"], lw = 2)
    xlabel!("Epochs")
    ylabel!("Accuracy")
end


plot_history(training_accuracies, val_accuracies)

# %% [markdown]
# Evaluation

# %%
mlp = ThreeLayerPerceptron(128, no_pixels^2, no_labels)
mlp = load_model(FILE_PATH, mlp);

# %% [markdown]
# To do:
#
#  * Complete helper functions to plot history of training
#  * Implement different optimization algorithms and learning rate schedules
#  * Evaluation
#  * Consider a deployable version of this problem. Learn params, deploy in JS

# %% [markdown]
# ## Adam

# %%
mutable struct Adam
    alpha::Float64
    beta_1::Float64
    beta_2::Float64
    epsilon::Float64
    parameter_vec::Vector{Float64}
    moment_vec_1::Vector{Float64}
    moment_vec_2::Vector{Float64}
    time_step::Int64
end

function Adam(alpha, beta_1, beta_2, epsilon, model)
    params = flatten(model)
    size = length(params)
    return Adam(alpha, beta_1, beta_2, epsilon, params, zeros(size), zeros(size), 0)
end

function step!(opt::Adam, model::ThreeLayerPerceptron, gradm::ThreeLayerPerceptron)
    gradm = flatten(gradm)
    opt.time_step += 1
    opt.moment_vec_1 = opt.beta_1 * opt.moment_vec_1 .+ (1 - opt.beta_1) .* gradm
    opt.moment_vec_2 = opt.beta_2 * opt.moment_vec_2 .+ (1 - opt.beta_2) .* gradm.^2
    
    bias_corrected_vec_1 = opt.moment_vec_1 / (1 - opt.beta_1^opt.time_step)
    bias_corrected_vec_2 = opt.moment_vec_2 / (1 - opt.beta_2^opt.time_step)
    
    opt.parameter_vec .-= opt.alpha .*  bias_corrected_vec_1 ./ (sqrt.(bias_corrected_vec_2) .+ opt.epsilon)
    
    unflatten!(model, opt.parameter_vec)
end
# Out:
# step! (generic function with 2 methods)

# %%
FILE_PATH = "model_params/mlp_adam_params.txt"

BATCH_SIZE = 64
MAX_EPOCHS = 500
BEST_VAL_ACC = 0
BEST_MODEL = 0

loss_list = []
training_accuracies = []
val_accuracies = []

mlp = ThreeLayerPerceptron(128, no_pixels^2, no_labels)
opt = Adam(0.001, 0.9, 0.999, 1e-8, mlp)

for epoch in 1:MAX_EPOCHS
    
    epoch_loss = 0
    batches = batchify(train_idx, BATCH_SIZE, true)
    
    @Threads.threads for batch in batches
        
        batch_loss = 0
        gradm = zero(mlp)
        
        for i in batch
            
            x_train = train_x[i, :]
            y_train = train_y[i]
            
            # Compute loss
            batch_loss += loss(mlp, x_train, y_train)
            
            # Calculate the gradient
            lossprime!(gradm, mlp, x_train, y_train)
        end
        
        epoch_loss += batch_loss
        
        # We take a step in the direction of the gradient

        step!(opt, mlp, gradm)
        
    end
    
    training_accuracy = accuracy(mlp, train_x[train_idx, :], train_y[train_idx])
    val_accuracy      = accuracy(mlp, train_x[val_idx, :], train_y[val_idx])

    @printf("Epoch: %.0f \t || \t Train Accuracy: %.4f \t || \t Validation Accuracy: %.4f \n", epoch, training_accuracy, val_accuracy)
    
    append!(training_accuracies, training_accuracy)
    append!(val_accuracies, val_accuracy)
    append!(loss_list, epoch_loss)
    
    if val_accuracy > BEST_VAL_ACC
        BEST_VAL_ACC = val_accuracy
        BEST_MODEL = deepcopy(mlp)
    end
    
    training_accuracy < 1.0 || break
    if epoch > 10 && (val_accuracies[end] - minimum(val_accuracies[end-(10-1):end-1]) < 0.0001)
        println("Early Stopping Condition Met")
        break
    end
end

save_model(FILE_PATH, BEST_MODEL)
# Out:
# Epoch: 1 	 || 	 Train Accuracy: 0.8173 	 || 	 Validation Accuracy: 0.8061
# Epoch: 2 	 || 	 Train Accuracy: 0.8826 	 || 	 Validation Accuracy: 0.8678
# Epoch: 3 	 || 	 Train Accuracy: 0.9133 	 || 	 Validation Accuracy: 0.8950
# Epoch: 4 	 || 	 Train Accuracy: 0.9275 	 || 	 Validation Accuracy: 0.9069
# Epoch: 5 	 || 	 Train Accuracy: 0.9416 	 || 	 Validation Accuracy: 0.9181
# Epoch: 6 	 || 	 Train Accuracy: 0.9515 	 || 	 Validation Accuracy: 0.9242
# Epoch: 7 	 || 	 Train Accuracy: 0.9617 	 || 	 Validation Accuracy: 0.9313
# Epoch: 8 	 || 	 Train Accuracy: 0.9662 	 || 	 Validation Accuracy: 0.9327
# Epoch: 9 	 || 	 Train Accuracy: 0.9732 	 || 	 Validation Accuracy: 0.9368
# Epoch: 10 	 || 	 Train Accuracy: 0.9776 	 || 	 Validation Accuracy: 0.9361
# Epoch: 11 	 || 	 Train Accuracy: 0.9796 	 || 	 Validation Accuracy: 0.9387
# Epoch: 12 	 || 	 Train Accuracy: 0.9822 	 || 	 Validation Accuracy: 0.9377
# Epoch: 13 	 || 	 Train Accuracy: 0.9864 	 || 	 Validation Accuracy: 0.9428
# Epoch: 14 	 || 	 Train Accuracy: 0.9894 	 || 	 Validation Accuracy: 0.9435
# Epoch: 15 	 || 	 Train Accuracy: 0.9908 	 || 	 Validation Accuracy: 0.9434
# Epoch: 16 	 || 	 Train Accuracy: 0.9938 	 || 	 Validation Accuracy: 0.9453
# Epoch: 17 	 || 	 Train Accuracy: 0.9949 	 || 	 Validation Accuracy: 0.9468
# Epoch: 18 	 || 	 Train Accuracy: 0.9963 	 || 	 Validation Accuracy: 0.9456
# Epoch: 19 	 || 	 Train Accuracy: 0.9968 	 || 	 Validation Accuracy: 0.9464
# Epoch: 20 	 || 	 Train Accuracy: 0.9977 	 || 	 Validation Accuracy: 0.9474
# Epoch: 21 	 || 	 Train Accuracy: 0.9978 	 || 	 Validation Accuracy: 0.9455
# Epoch: 22 	 || 	 Train Accuracy: 0.9990 	 || 	 Validation Accuracy: 0.9499
# Epoch: 23 	 || 	 Train Accuracy: 0.9994 	 || 	 Validation Accuracy: 0.9508
# Epoch: 24 	 || 	 Train Accuracy: 0.9994 	 || 	 Validation Accuracy: 0.9512
# Epoch: 25 	 || 	 Train Accuracy: 0.9997 	 || 	 Validation Accuracy: 0.9523
# Epoch: 26 	 || 	 Train Accuracy: 0.9996 	 || 	 Validation Accuracy: 0.9511
# Epoch: 27 	 || 	 Train Accuracy: 0.9999 	 || 	 Validation Accuracy: 0.9521
# Epoch: 28 	 || 	 Train Accuracy: 0.9999 	 || 	 Validation Accuracy: 0.9525
# Epoch: 29 	 || 	 Train Accuracy: 0.9999 	 || 	 Validation Accuracy: 0.9533
# Epoch: 30 	 || 	 Train Accuracy: 1.0000 	 || 	 Validation Accuracy: 0.9537

# %%
plot_history(training_accuracies, val_accuracies)
